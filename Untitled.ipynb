# %%
from scripts.train import train_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scripts.train import train_model
#
# File ~/mldl/mldl_project/scripts/train.py:4
#       2 import torch.optim as optim
#       3 from torch.utils.data import DataLoader
# ----> 4 import yaml
#       5 import multiprocessing
#       6 import os
#
# ModuleNotFoundError: No module named 'yaml'

# %%
train_model(num_epochs=300)
# Out:
# /home/raciard/.local/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/raciard/.local/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
# Epoch 1/300 - Val:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 1/300 - Train Loss: 0.0703 - Val Loss: 0.0498
# ✅ Nuovo modello migliore salvato.
# ...
# Epoch 2/300 - Val:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 2/300 - Train Loss: 0.0393 - Val Loss: 0.0268
# ✅ Nuovo modello migliore salvato.
# ...
