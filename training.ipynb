# %%
from scripts.train import train_model
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
train_model(num_epochs=300, use_lmdb=True)
# Out:
# /home/raciard/.conda/envs/tp3d/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/raciard/.conda/envs/tp3d/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
# Epoch 1/300 - Val:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 1/300 - Train Loss: 0.0713 - Val Loss: 0.0497
# ✅ Nuovo modello migliore salvato.
# ...
# Epoch 2/300 - Val:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 2/300 - Train Loss: 0.0380 - Val Loss: 0.0240
# ✅ Nuovo modello migliore salvato.
# ...

# %%
import lmdb
import pickle
from tqdm import tqdm

def save_complex_dataset_to_lmdb(dataset, lmdb_path):
    env = lmdb.open(lmdb_path, map_size=1e12)
    with env.begin(write=True) as txn:
        for idx in tqdm(range(len(dataset)), desc="Writing complex data to LMDB"):
            example = dataset[idx]  # può essere qualunque cosa serializzabile
            txn.put(f'{idx:08d}'.encode(), pickle.dumps(example))
        txn.put(b'__len__', pickle.dumps(len(dataset)))

# %%
save_complex_dataset_to_lmdb(train_dataset, "lmdb")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 save_complex_dataset_to_lmdb(train_dataset, "lmdb")
#
# NameError: name 'train_dataset' is not defined
