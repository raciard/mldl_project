# %%
# !git clone https://raciard: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@github.com/raciard/mldl_project.git
# Out:
# Cloning into 'mldl_project'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 54 (delta 18), reused 39 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 2.55 MiB | 5.27 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.empty_cache()

# %%
from data.dataset import LinemodDataset

# %%
from torch.utils.data import DataLoader
from scripts.train import train_model
from model.model import PoseModel
from model.loss import PoseLoss


dataset_root = "datasets/Linemod_preprocessed/"

train_dataset = LinemodDataset(dataset_root, split='train')
val_dataset = LinemodDataset(dataset_root, split='test')

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=8)
model = PoseModel()

train_model(model, train_loader, val_loader=val_loader, num_epochs=5)
# Out:
# /usr/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_V2_S_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_V2_S_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 790/790 [01:04<00:00, 12.30it/s]
# Epoca [1/5], Loss: 0.4478
# ...

# %%
train_model(model, train_loader, val_loader=val_loader, num_epochs=20)
# Out:
# 100%|██████████| 395/395 [07:21<00:00,  1.12s/it]
# Epoca [1/20], Loss: 9.1452
# 100%|██████████| 790/790 [01:48<00:00,  7.30it/s]
# Validazione, Loss: 8.9557
# Salvato modello migliore con loss di validazione: 8.9557
# Salvato modello: checkpoints/pose_cnn_epoch_1.pth
# 100%|██████████| 395/395 [07:02<00:00,  1.07s/it]
# Epoca [2/20], Loss: 7.5441
# 100%|██████████| 790/790 [01:35<00:00,  8.26it/s]
# Validazione, Loss: 6.8739
# Salvato modello migliore con loss di validazione: 6.8739
# Salvato modello: checkpoints/pose_cnn_epoch_2.pth
# 100%|██████████| 395/395 [06:58<00:00,  1.06s/it]
# Epoca [3/20], Loss: 7.2198
# 100%|██████████| 790/790 [01:35<00:00,  8.29it/s]
# Validazione, Loss: 6.6403
# Salvato modello migliore con loss di validazione: 6.6403
# Salvato modello: checkpoints/pose_cnn_epoch_3.pth
# 100%|██████████| 395/395 [06:48<00:00,  1.03s/it]
# Epoca [4/20], Loss: 6.7310
# 100%|██████████| 790/790 [01:36<00:00,  8.20it/s]
# Validazione, Loss: 6.9896
# ...

# %%
entry = val_dataset[1]
image = entry['cropped_img']
label = entry['obj_id']
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
translation, rotation = model(image.unsqueeze(0).to(device), label.unsqueeze(0).long().to(device))
print(rotation, translation)
# Out:
# tensor([[-0.4299, -0.6404, -0.5690,  0.2850]], device='cuda:0',
#        grad_fn=<DivBackward0>) tensor([[-0.1448, -0.8336,  0.5689]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
from scripts.train import rotation_matrix_to_quaternion
print(entry['translation'])
print(rotation_matrix_to_quaternion(entry['rotation']))
# Out:
# tensor([-89.9653, -50.0827, 705.0745])
# tensor([ 0.3058,  0.4904,  0.7647, -0.2849])

# %%
# %rm -rf mldl_project/
